# %% [markdown]
# # 검색 최적화를 위한 Indexing
#
# Indexing(인덱싱)은 외부 문서를 검색할 수 있는 형태로 변환해 저장하는 준비 과정이다. 이 실습에서는 공개된 `documents.csv`를 직접 내려받고, 각 본문을 OpenAI 임베딩 벡터로 변환해 Pinecone에 저장한다.
#
# 이름이 비슷한 세 용어의 역할은 다음과 같다.
#
# - **Indexing**: 문서 준비부터 임베딩과 저장까지 수행하는 과정이다.
# - **Pinecone index**: 벡터, 문서 식별자와 메타데이터가 저장되는 원격 검색 공간이다.
# - **PineconeVectorStore**: LangChain 코드에서 Pinecone index의 저장과 검색 기능을 호출하는 연결 객체이다.
#
# 전체 데이터 흐름은 `CSV 행 → Document → embedding vector → Pinecone index → 유사 문서와 점수`이다. 같은 `doc_id`를 Pinecone 레코드 ID로 사용하면 노트북을 다시 실행해도 같은 문서를 갱신할 수 있다.

# %% [markdown]
# ## Indexing 실행 패키지 준비

# %%
# %pip install -U pandas langchain langchain-openai langchain-pinecone pinecone python-dotenv gdown
# Out:
# Requirement already satisfied: pandas in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (3.0.5)
# Requirement already satisfied: langchain in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.3.15)
# Requirement already satisfied: langchain-openai in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.4.3)
# Requirement already satisfied: langchain-pinecone in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (0.2.13)
# Requirement already satisfied: pinecone in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (7.3.0)
# Collecting pinecone
#   Using cached pinecone-9.1.0-cp310-abi3-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: python-dotenv in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.2.2)
# Requirement already satisfied: gdown in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (6.1.0)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pandas) (2.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.5.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain) (1.5.4)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2.0.0,>=1.5.4->langchain) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.4->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: openai<3.0.0,>=2.45.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (2.52.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai<3.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: regex in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: simsimd>=5.9.11 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-pinecone) (6.5.16)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pinecone) (2.7.0)
# Requirement already satisfied: aiohttp>=3.9.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (3.14.3)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.4->langchain) (3.4.9)
# Requirement already satisfied: beautifulsoup4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from gdown) (4.15.0)
# Requirement already satisfied: filelock in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from gdown) (3.32.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp>=3.9.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.24.5)
# Requirement already satisfied: six>=1.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tqdm>4->openai<3.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from beautifulsoup4->gdown) (2.9.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## API key 환경 변수 준비
#
# `load_dotenv()`로 `.env`의 OpenAI·Pinecone API key를 환경 변수에 등록한다. 키 값은 출력하지 않으며 뒤의 `Pinecone()`과 `OpenAIEmbeddings`가 필요한 인증값을 직접 읽는다.

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=False)
# Out:
# True

# %% [markdown]
# ## Pinecone index와 임베딩 설정
#
# `PINECONE_NAMESPACE`는 하나의 index 안에서 레코드 묶음을 논리적으로 분리하는 이름이다. 값이 없으면 Pinecone의 기본 namespace인 빈 문자열을 사용한다. 이후 BM25·Dense 비교와 RRF가 같은 벡터를 검색하려면 세 노트북이 같은 index 이름과 namespace를 사용해야 한다.
#
# 기본 설정은 `text-embedding-3-small`의 1,536차원 벡터를 사용하고, cosine similarity score를 해석하기위해 Pinecone metric은 `cosine`만 허용한다.

# %%
PINECONE_INDEX_NAME = os.getenv('PINECONE_INDEX_NAME', 'adv-rag')
PINECONE_NAMESPACE = os.getenv('PINECONE_NAMESPACE', '').strip()
PINECONE_INDEX_CLOUD = os.getenv('PINECONE_INDEX_CLOUD', 'aws')
PINECONE_INDEX_REGION = os.getenv('PINECONE_INDEX_REGION', 'us-east-1')
PINECONE_INDEX_METRIC = os.getenv(
    'PINECONE_INDEX_METRIC', 'cosine'
).strip().lower()
PINECONE_INDEX_DIMENSION = int(os.getenv('PINECONE_INDEX_DIMENSION', '1536'))
OPENAI_EMBEDDING_MODEL = os.getenv(
    'OPENAI_EMBEDDING_MODEL', 'text-embedding-3-small'
).strip() or 'text-embedding-3-small'

# %% [markdown]
# ## Pinecone index 생성 또는 재사용
#
# `Pinecone()`은 `.env`의 `PINECONE_API_KEY`를 이용해 Pinecone 관리 API에 연결한다. `create_index()`의 주요 인자는 다음 역할을 가진다.
#
# - `name`: 저장과 검색에 사용할 index 식별자이다.
# - `dimension`: 한 벡터의 숫자 개수이며 임베딩 출력 차원과 같아야 한다.
# - `metric`: 벡터 사이의 가까움을 계산하는 방식이다.
# - `ServerlessSpec`: index를 배치할 cloud와 region을 지정한다.
#
# 같은 이름이 없을 때만 index를 생성하고, 이미 있으면 재사용한다. 생성 요청은 index 준비보다 먼저 끝날 수 있으므로 다음 셀에서 `ready` 상태를 확인한다. [Pinecone index 관리 문서](https://docs.pinecone.io/guides/manage-data/manage-indexes)

# %%
from pinecone import Pinecone, ServerlessSpec

# 1. Pinecone 연결 객체 생성
# - API KEY 생략 시 환경 변수에서 PINECONE_API_KEY를 찾아 등록
pc = Pinecone()

# 해당 사용자가 보유하고 있는 index 목록 반환
existing_indexes = pc.list_indexes().names()
print(existing_indexes)


# 2. Pinecone에 Serverless index 생성 요청 보내기
# 단, 같은 이름의 index가 없을 경우에만...
if PINECONE_INDEX_NAME not in existing_indexes:
    pc.create_index(
        name=PINECONE_INDEX_NAME, # adv-rag
        dimension=PINECONE_INDEX_DIMENSION, # 1536
        metric=PINECONE_INDEX_METRIC, # cosine
        spec=ServerlessSpec(
            cloud=PINECONE_INDEX_CLOUD, # aws
            region=PINECONE_INDEX_REGION # us-east-1
        )
    )
    print(f"Index {PINECONE_INDEX_NAME} 생성 요청 완료.")

else:
    print(f"{PINECONE_INDEX_NAME} index가 이미 존재하여 재사용함")
# Out:
# ['winemag-review-data', 'pinecone-first']
# Index adv-rag 생성 요청 완료.

# %% [markdown]
# ## index가 적재 가능한 상태인지 확인
#
# `create_index()`는 생성 요청을 보낸 뒤 실제 준비가 끝나기 전에 반환될 수 있다. 다음 코드는 `ready=True`가 될 때까지 기다린 뒤 바로 Vector Store 연결 단계로 넘어간다.

# %%
from time import sleep

# health check: 통신 가능 상태인지 확인
while not pc.describe_index(
        name=PINECONE_INDEX_NAME).status['ready']:
    sleep(1) # 1초마다 준비상태 조회

print("index ready:", PINECONE_INDEX_NAME)
# Out:
# index ready: adv-rag

# %% [markdown]
# ## 임베딩 모델과 PineconeVectorStore 연결
#
# `OpenAIEmbeddings`는 텍스트를 숫자 벡터로 변환하는 객체이다. `PineconeVectorStore`는 Pinecone 자체가 아니라, LangChain에서 Pinecone index에 문서를 저장하고 검색하기 위한 연결 객체이다.
#
# - `model`: 텍스트를 어떤 방식과 가중치로 벡터화할지 정하는 임베딩 모델이다.
# - `dimensions`: 생성할 문서·query 벡터의  숫자 개수이다. Pinecone index의 `dimension`과 같아야 한다.
# - `index_name`: 앞에서 준비한 Pinecone index를 선택한다.
# - `embedding`: 저장할 본문과 검색 질문을 같은 벡터 공간으로 변환한다.
# - `namespace`: 해당 index 안에서 저장과 검색이 사용할 동일한 레코드 영역을 선택한다.
#
# 문서와 질문에는 같은 `model`과 `dimensions`를 사용한다. 생성된 벡터 길이가 Pinecone index dimension과 다르거나 저장과 검색의 namespace가 다르면 정상적으로 저장·검색할 수 없다. [LangChain Pinecone 연동 문서](https://docs.langchain.com/oss/python/integrations/vectorstores/pinecone)

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore

# 1. OpenAI Embedding Model 생성
embeddings = OpenAIEmbeddings(
    model=OPENAI_EMBEDDING_MODEL, # text-embedding-3-small
    dimensions=PINECONE_INDEX_DIMENSION, # 1536
)

# 2. Pinecone Vector Store 연결
vector_store = PineconeVectorStore(
    index_name=PINECONE_INDEX_NAME, # adv-rag
    embedding=embeddings,
    namespace=PINECONE_NAMESPACE, # "" (__default__)
)

# 실행해서 오류가 발생하지 않으면 연결 성공!

# %% [markdown]
# ## documents.csv 다운로드
#
# Google Drive에 공개된 수업용 `documents.csv`를 내려받는다. `gdown`의 파일 ID는 실제 문서 데이터 위치를 가리키고, `-O documents.csv`는 다음 `pd.read_csv()` 셀이 사용할 로컬 파일명을 정한다. 이 셀은 네트워크 다운로드를 수행하므로 수업 환경에서 인터넷 연결을 확인한 뒤 실행한다.

# %%
# !gdown 1pspaw_q4_QCp2K4M-thDlUtra-_wQI7k -O documents.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1pspaw_q4_QCp2K4M-thDlUtra-_wQI7k
# To: C:\SKN_AI\09_llm\07_advanced_rag\01_retrieval_optimization\documents.csv
#
#   0%|          | 0.00/14.9k [00:00<?, ?B/s]
# 100%|██████████| 14.9k/14.9k [00:00<?, ?B/s]

# %% [markdown]
# ## CSV 읽기
#
# Pandas의 `pd.read_csv()`는 내려받은 `documents.csv`를 행과 열로 구성된 `DataFrame`으로 읽는다. 한 행이 뒤에서 하나의 `Document`가 된다.
#
# 먼저 전체 shape와 열 이름을 출력하고  문서 세 건을 확인한다. 이어지는 셀에서 이 표가 인덱싱에 필요한 schema를 만족하는지 검사한다.

# %%
import pandas as pd
documents_df = pd.read_csv('documents.csv')

print('documents shape:', documents_df.shape)
print('documents columns:', documents_df.columns.tolist())
display(documents_df.head(3))
# Out:
# documents shape: (30, 3)
# documents columns: ['doc_id', 'title', 'content']
#   doc_id               title  \
# 0     D1          제주도 여행 가이드
# 1     D2  전주 비빔밥과 진주 비빔밥 차이점
# 2     D3         걸스데이 히트곡 분석
#
#                                              content
# 0  제주도는 대한민국의 대표 관광지로서, 한라산 등반, 성산 일출봉 관광, 해변 활동(...
# 1  비빔밥은 조선 시대부터 전해 내려온 대표적 한국 음식으로, 밥 위에 고명(채소·고기...
# 2  걸스데이는 2010년 데뷔한 대한민국의 4인조 걸그룹으로, 대표곡으로는 “Somet...

# %% [markdown]
# ## DataFrame 행을 인덱싱 입력으로 변환
#
# `iterrows()`는 DataFrame을 한 행씩 순회하며 `(행 index, Series)`를 반환한다. 여기서는 행 번호가 필요하지 않으므로 `_`로 받고, 각 `Series`에서 `doc_id`와 `content`를 꺼낸다.
#
# 변환 결과인 `(문서 ID, 본문)` 튜플 목록은 다음 셀에서 `Document` 목록과 Pinecone 레코드 ID 목록으로 분리된다.

# %%
docs_to_index = []

# iterrows(): Dataframe의 한 줄을 (행 번호, 행) 형태로 반환
for _, row in documents_df.iterrows():
    doc_id = str(row['doc_id'])
    content = str(row['content'])
    docs_to_index.append((doc_id, content))

print(len(docs_to_index)) # 30
print("first document ID:", docs_to_index[0][0])
print("first document Content:", docs_to_index[0][1])
# Out:
# 30
# first document ID: D1
# first document Content: 제주도는 대한민국의 대표 관광지로서, 한라산 등반, 성산 일출봉 관광, 해변 활동(협재해수욕장·함덕해수욕장) 등이 인기입니다. 현지 음식으로는 흑돼지, 고기국수, 전복죽 등이 있으며, 카페 거리(서귀포시 대정읍 카페 거리)도 유명합니다. 교통은 렌터카나 시외버스를 주로 이용하며, 사전 예약 시 우도 투어나 올레길 트레킹도 즐길 수 있습니다.

# %% [markdown]
# ## Document 생성과 고정 ID upsert
#
# `Document`는 LangChain이 문서 본문과 부가 정보를 함께 다루는 표준 객체이다.
#
# - `page_content`: OpenAI 임베딩 모델에 전달되는  본문이다.
# - `metadata`: 벡터와 함께 저장되며 검색 뒤 문서 ID를 복원한다.
# - `ids`: Pinecone에서 각 레코드를 구분하는 고정 ID 목록이다.
#
# `add_documents()`를 호출하면 `page_content → OpenAI embedding → Pinecone vector upsert`가 실행된다. Upsert는 ID가 없으면 새 레코드를 만들고, 같은 ID가 있으면 그 레코드를 갱신하는 저장 방식이다. 문서 목록과 ID 목록을 한 번에 전달해 CSV의 문서 30건을 `PINECONE_NAMESPACE` 영역에 batch로 처리한다.

# %%
from langchain_core.documents import Document

# 1. documents와 document_ids list 생성
documents = []
document_ids = []

# 2. docs_to_index의 요소를 얻어와 LangChain Document 변환
# + 1번에서 생성한 list에 누적
for doc_id, content in docs_to_index:
    document = Document(
        page_content=content,
        metadata={'doc_id': doc_id}
    )

    documents.append(document)
    document_ids.append(doc_id)
    # 각 list의 같은 인덱스 요소가 한 세트를 이루게 만듦.

# 3. Vector Store에 Documents 추가
# - 단순 insert X
# -> 고정 id를 제공해서 Vector Store에 같은 id가 없다면 insert
#    중복되는 id가 있다면 update를 하는 upsert 진행
upsert_ids = vector_store.add_documents(
    documents=documents,
    ids=document_ids,
)

print('입력된 Document 수:', len(documents))
print('upsert결과로 반환된 id 수:', len(upsert_ids))
# Out:
# 입력된 Document 수: 30
# upsert결과로 반환된 id 수: 30

# %% [markdown]
# ## 질문 임베딩과 상위 5개 검색
#
# `similarity_search_with_score()`는 질문을 문서와 같은 OpenAI 모델로 임베딩한 뒤 `vector_store`에 설정된 동일한 namespace에서 가까운 벡터를 찾는다.
#
# - `query`: 검색할 자연어 질문이다.
# - `k=5`: 최대 다섯 건을 반환한다.
# - 반환값: 유사한 순서의 `list[tuple[Document, float]]`이다. 각 튜플의 첫 값은 원문과 메타데이터를 가진 `Document`, 둘째 값은 cosine similarity score이다.
#
# 현재 `cosine` 구성에서는 score가 큰 문서부터 반환되며, 높은 값일수록 질문과 더 유사하다. 이 score는 모델이 정답일 확률이 아니라 두 embedding vector가 얼마나 같은 방향을 가리키는지 나타내는 값이다.

# %%
results: list[tuple[Document, float]] = vector_store.similarity_search_with_score(
    query="제주도 관광지",
    k=5
)

for rank, (document, score) in enumerate(results, start=1):
    print(
        f'{rank}: {document.metadata["doc_id"]} '
        f'(cosine similarity: {score:.4f})'
    )
    print(document.page_content)
    print()
# Out:
# 1: D1 (cosine similarity: 0.5894)
# 제주도는 대한민국의 대표 관광지로서, 한라산 등반, 성산 일출봉 관광, 해변 활동(협재해수욕장·함덕해수욕장) 등이 인기입니다. 현지 음식으로는 흑돼지, 고기국수, 전복죽 등이 있으며, 카페 거리(서귀포시 대정읍 카페 거리)도 유명합니다. 교통은 렌터카나 시외버스를 주로 이용하며, 사전 예약 시 우도 투어나 올레길 트레킹도 즐길 수 있습니다.
#
# 2: D12 (cosine similarity: 0.3090)
# 서울 근교에서 당일치기로 다녀올 만한 여행지로는 가평 쁘띠프랑스, 남양주 수종사, 양평 두물머리, 용인 에버랜드 등이 있습니다. 기차·버스 노선이 잘 발달되어 있어 대중교통으로 이동이 편리하며, 차가 있다면 경춘고속도로를 이용해 접근성이 좋습니다. 사전 관광 예약 앱(예: 야놀자, 쿠팡트래블)에서도 할인 혜택을 확인할 수 있습니다.
#
# 3: D13 (cosine similarity: 0.2310)
# 비빔밥은 지역별로 칼로리, 탄수화물, 단백질, 지방 함량이 차이를 보입니다. 전주 비빔밥(약 650kcal)은 채소·고기·계란 비율이 고르지만, 진주 비빔밥(약 700kcal)은 해산물과 육류가 섞여 열량이 다소 높습니다. 안동 비빔밥은 재료가 비교적 간단해 600kcal 내외이며, 지역별 나물 종류와 기름 사용량이 칼로리 차이에 영향을 미칩니다.
#
# 4: D2 (cosine similarity: 0.2278)
# 비빔밥은 조선 시대부터 전해 내려온 대표적 한국 음식으로, 밥 위에 고명(채소·고기·계란 등)을 올리고 고추장이나 간장을 섞어 먹습니다. 전주 비빔밥은 고명 종류가 다양하고 전주식 고추장을 쓰며, 잔치용으로도 유명합니다. 진주 비빔밥은 고기·회·나물 등을 섞어 더욱 풍부한 식감을 제공합니다. 두 지역 모두 역사적 배경과 재료 구성이 달라 맛과 풍미가 다릅니다.
#
# 5: D8 (cosine similarity: 0.1971)
# 서울 지하철은 1호선부터 9호선까지 운행되며, 주요 환승역으로는 서울역·강남역·종로3가역·고속터미널역 등이 있습니다. 기본 요금은 1,250원(성인 기준)이며, 거리에 따른 추가 요금이 부과됩니다. T-money 교통카드를 사용하면 자동으로 할인 적용이 됩니다. 출퇴근 시간대에는 혼잡하므로 가급적 비혼잡 시간대를 이용하고, 5호선 공덕역 환승 구간 등을 주의해야 합니다.
